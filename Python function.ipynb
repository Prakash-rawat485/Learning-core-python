# %% [markdown]
# # Python function:
# - **python funciton are a block of statements that does a specific task.The idea is to put some commonly or repeatedly done task together and make a function so that instead of writing the same code again and again for differen inputs,we can do the function calls to reuse code contained in it over and over again.**

# %%
def multiply(n1,n2):
    n3=n1*n2
    return n3

# %%
multiply(11,11)
# Out:
# 121

# %%
def fun():
    print('Welcome to AI')

# %%
fun()
# Out:
# Welcome to AI

# %%
def fun():
    return('Welcome to AI')

# %%
fun()
# Out:
# 'Welcome to AI'
