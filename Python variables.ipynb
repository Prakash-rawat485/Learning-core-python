# %% [markdown]
# #  python variable
# - In python variables are used to restore data that can be referenced and manupulated during solving the problems.
# - A variable is assigned a value.In python it is not necessary to declare the data type during assignment of a variable.
# - Variable act as a placeholder of data.

# %%
name='Prakash'
print(name)
# Out:
# Prakash

# %%
print('name')
# Out:
# name

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
x=50
print(x)
# Out:
# 50

# %% [markdown]
# # Rule for naming variable.
# - variable names can only contain letter,digits and underscores(_).
# - A variable name cannot start with a digit.
# - Variable names are case sensitive.
# - Avoid using python keywords.

# %% [markdown]
# # rule 1-

# %%
 no_of_students=90
print(no_of_students)
# Out:
# 90

# %%
1=90                          # wrong as it cannot start with a numerical value
# Out:
#   Cell In[11], line 1
#     1=90                          # wrong as it cannot start with a numerical value
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
_students=43
print(_students)
# Out:
# 43

# %%
total-student=89
print(total-student)
# Out:
#   Cell In[14], line 1
#     total-student=89
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# # rule2_

# %%
9_student=98
print(9_student)
# Out:
#   Cell In[15], line 1
#     9_student=98
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # rule3-

# %%
x=43
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 x=43
# ----> 2 print(X)
#
# NameError: name 'X' is not defined

# %% [markdown]
# # rule4

# %%
True=32
print(True)
# Out:
#   Cell In[18], line 1
#     True=32
#     ^
# SyntaxError: cannot assign to True

# %% [markdown]
# # Dynamic typing
# - Python variables are dynamically typed.

# %%
x=43
print(x)
x='Prakash'
print(x)
# Out:
# 43
# Prakash

# %% [markdown]
# # Multiple assignment.
# - Python allows multiple variables in a single line.

# %%
a=13
b=13
c=13
a=b=c
print(a)
# Out:
# 13

# %%
print(b)
# Out:
# 13

# %%
print(c)
# Out:
# 13

# %%
print(a,b,c)
# Out:
# 13 13 13

# %% [markdown]
# # Assigning different values.
# - Pyhton allows different values to multiple variables.

# %%
a=12
b=42
c=52
z='Prakash'
print(a,b,c,z)
# Out:
# 12 42 52 Prakash

# %%
x,y,z=12,42,'deepak'
print(x)
# Out:
# 12

# %%
print(y)
# Out:
# 42

# %%
print(z)
# Out:
# deepak

# %%
x=42.44
i=True
y='prakash rawat '
print(x)
# Out:
# 42.44

# %%
print(y,x,i)
# Out:
# prakash rawat  42.44 True
