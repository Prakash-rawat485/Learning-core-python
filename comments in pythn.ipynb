# %% [markdown]
# # Escape sequences:

# %% [markdown]
# #### \n Represents a newline character.
# ####  \t Represents a tab character.
# #### - Double backlash Represents a literal backslash.

# %%
print('Prakash\n has recently joined\na\ttraining institute\nand the institue is near \\Gokul dham colony')
# Out:
# Prakash
#  has recently joined
# a	training institute
# and the institue is near \Gokul dham colony

# %%
print('I am a\nvolleyball player\n\t-state')
# Out:
# I am a
# volleyball player
# 	-state

# %%
print('I have also played many other\nsports like- badminton,table tenis')
# Out:
# I have also played many other
# sports like- badminton,table tenis

# %%
print('Its been a week since i\njoined a AI robotics institute.\nits near\\Gokul dham colony near Eco town.')
# Out:
# Its been a week since i
# joined a AI robotics institute.
# its near\Gokul dham colony near Eco town.
