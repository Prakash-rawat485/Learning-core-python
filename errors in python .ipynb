# %%
Print('hello world)
# Out:
#   Cell In[3], line 1
#     Print('hello world)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# **types of error**

# %% [markdown]
# - ***the name error- NameError: name 'Print' is not defined***.
#
# - ***the syntax error-SyntaxError: unterminated string literal (detected at line 1)***.
#
# - ***TypeError***:   ****list.append() takes exactly one argument (4 given)****

# %% [markdown]
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 list1.append('deepakraj',43,23,53)
#       2 print(list1)
#
# TypeError: list.append() takes exactly one argument (4 given)

# %% [markdown]
# # Comments in python

# %%
print('I am writing comment')             # i am practising python
# Out:
# I am writing comment

# %%
print('Today is my second class')           # timming is from 12-1
# Out:
# Today is my second class

# %%
print('firstly we started python')             # started the basic python
# Out:
# firstly we started python

# %%
print('Every code is a statement')
# Out:
# Every code is a statement

# %% [markdown]
# - # the comments are made on the statement.

# %%
# is used to make heading  in markdown

# %% [markdown]
# # for bullet points put - befor the word

# %% [markdown]
# # how was the day?
# - a good day
# - a perfect start

# %%
print("*")
print("*  *") 
print("*    *") 
print("*      *") 
print("*        *") 
print("*          *") 
print("*            *") 
print("*              *") 
print("* * * * * * * *  *")
# Out:
# *
# *  *
# *    *
# *      *
# *        *
# *          *
# *            *
# *              *
# * * * * * * * *  *

# %%
print('*\n* *\n*  *\n*   *\n*    *\n*     *\n* *  * *')
# Out:
# *
# * *
# *  *
# *   *
# *    *
# *     *
# * *  * *

# %%
print('*\n*\t*\n\t*  *\n*\t*\n*    *\n*     *\n* *  * *')
# Out:
# *
# *	*
# 	*  *
# *	*
# *    *
# *     *
# * *  * *

# %%
print('\t*\n\t**\n\t***\n\t****\n\t*****\n\t******\n\t*******\n\t********')
# Out:
# 	*
# 	**
# 	***
# 	****
# 	*****
# 	******
# 	*******
# 	********

# %%
print('\t*\n       * *\n      * * *\n     * * * *\n    * * * * *')
# Out:
# 	*
#        * *
#       * * *
#      * * * *
#     * * * * *

# %% [markdown]
# # points to remember while doing above kind of work.
# - proper use of \n
# - proper spacing
# - the \t is providing us with space as u can see above somewhere it should be avoided and instead of it use spacing
