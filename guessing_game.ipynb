# %%
import random

# %%
jackpot=random.randint(1,100)
guess=int(input('chal bol:'))
counter=1
while guess!=jackpot:
    if guess<jackpot:
        print('are thoda upper bata')
    else:
        print('thoda or neeche')
    guess=int(input('chal bol:'))
    counter+=1
print('7 crore')
print(f'abe tune {counter} baar mai bataya ye')
# Out:
# chal bol: 40
# thoda or neeche
# chal bol: 30
# thoda or neeche
# chal bol: 20
# are thoda upper bata
# chal bol: 25
# 7 crore
# abe tune 4 baar mai bataya ye
